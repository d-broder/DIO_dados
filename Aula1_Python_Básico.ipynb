# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
#Este é um comentátio em Python

# %%
#Soma
1+1
# Out:
# 2

# %%
2#Subtração
200-10
# Out:
# 190

# %%
#Mutliplicação
3 * 4
# Out:
# 12

# %%
#Divisão
10 / 2
# Out:
# 5.0

# %%
a = 10
b = 15

# %%
a + b
# Out:
# 25

# %%
#Criando uma variável tipo string
frase = "Python para análise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:5]
# Out:
# 'Pytho'

# %%
frase[:4]
# Out:
# 'Pyth'

# %%
frase[4:]
# Out:
# 'on para análise de dados'

# %%
frase[:4] + frase[4:]
# Out:
# 'Python para análise de dados'

# %%
frase[2:5]
# Out:
# 'tho'

# %%
frase.count("dado")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace("Python", "Palavra")
# Out:
# 'Palavra para análise de dados'

# %%
#Não funciona
frase.replace("python", "teste")
# Out:
# 'Python para análise de dados'
